# %% [markdown]
# <a href="https://colab.research.google.com/github/agj313829-crypto/Ejercicios_python_finales/blob/main/claseDataclasesjuan26_02_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from dataclasses import dataclass
@dataclass
class Libro:
    _titulo:str
    _autor:str
    _isbn:str
    _precio:float
    @property
    def titulo(self) -> str:
      return self._titulo
    @property
    def autor(self) -> str:
      return self._autor
    @property
    def isbn(self) -> str:
      return self._isbn
    @property
    def precio(self) -> float:
      return self._precio

    @titulo.setter
    def titulo(self,valor:str) -> None:
      if isinstance(valor,str) and valor.strip():
        self._titulo = valor
      else:
        raise ValueError("el titulo debe ser un texto valido no vacío.")

    @autor.setter
    def autor(self,valor:str) -> None:
      if isinstance(valor,str) and valor.strip():
        self._autor = valor
      else:
          raise ValueError("el titulo debe ser un texto valido no vacío.")
    @isbn.setter
    def isbn(self,valor:str) -> None:
      if isinstance(valor,str) and valor.strip():
        self._isbn = valor
      else:
        raise ValueError("el titulo debe ser un texto valido no vacío.")
    @precio.setter
    def precio(self,valor:float) -> None:
      if isinstance(valor,(int,float)) and valor > 0:
        self._precio = float(valor)
      else:
          raise ValueError("el titulo debe ser un texto valido no vacío.")
    def _repr_(self) -> str:
      return(
          f"Libro titulo= '{self._titulo}', autor= '{self._autor}',"
          f"isbn='{self._isbn}, precio={self._precio}"
      )
def main() -> None:
    libro = Libro("phyton senior IA", "pedro perez", "123-456-789", 1200000)
    print("\n===INFORMACIÓN LIBRO==")
    print(libro)
    libro.precio =150000
    libro.titulo = "python avanzado 3.0"
    print("\n===Datos actualizados===")
    print(libro)
    libro.isbn = "987654321"
    print("\n===Datos actualizados===")
    print(libro)

if __name__ == "__main__":
  main()
# Out:
# ===INFORMACIÓN LIBRO==
# Libro(_titulo='phyton senior IA', _autor='pedro perez', _isbn='123-456-789', _precio=1200000)
#
# ===Datos actualizados===
# Libro(_titulo='python avanzado 3.0', _autor='pedro perez', _isbn='123-456-789', _precio=150000.0)
#
# ===Datos actualizados===
# Libro(_titulo='python avanzado 3.0', _autor='pedro perez', _isbn='987654321', _precio=150000.0)

# %%
class Proveedor:
  def __init__(self , nit,razon_social,nombre_contacto,correo,producto):
    self._nit = nit
    self._razon_social = razon_social
    self._nombre_contacto = nombre_contacto
    self._correo = corrreo
    self._producto = producto
def get_nit(self):
  return self.__nit
def set_nit(self_nuevo_nit):
 if isinstance(nueva_nit,(int,float)) and  nueva_nit >0:
  self.__nit = nuevo_nit
  else:
    print("El numero debe ser un numero positivo.")
def get_razon_social(self):
  return self.__razon_social
def get_nombre(self):
  return self.__nombre
def get_cotacto(self):
  return self.__contacto
