# %% [markdown]
# <a href="https://colab.research.google.com/github/agj313829-crypto/Ejercicios_python_finales/blob/main/ClaseLibroJuan05_02_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Libro: #crear la clase
  def __init__(self, codigo, nombre_libro,autor,precio):
      self.codigo = codigo
      self.nombre_libro = nombre_libro
      self.autor = autor
      self.precio = precio
mi_libro1 = Libro("Abc123","Don quijote","Miguel Cervantes",8000 )
mi_libro2 = Libro("Def456","Satanas", "Mario mendoza",20000)
mi_libro3 = Libro("Ghi789", "Sapiens", "Yubal noah jarari",30000)
print(mi_libro1.codigo)
print(mi_libro1.nombre_libro)
print(mi_libro1.autor)
print(mi_libro1.precio)

print(mi_libro2.codigo)
print(mi_libro2.nombre_libro)
print(mi_libro2.autor)
print(mi_libro2.precio)

print(mi_libro3.codigo)
print(mi_libro3.nombre_libro)
print(mi_libro3.autor)
print(mi_libro3.precio)


print(f"\nEl codigo de el libro es: {mi_libro1.codigo}")
print(f"El precio de el libro 1 es: {mi_libro1.precio}")
print(f"El autor de el libro 1 es: {mi_libro1.autor}")
print(f"El nombre de el libro es: {mi_libro1.nombre_libro}")

print(f"\nEl codigo de el libro es : {mi_libro2.codigo}")
print(f"El precio de el libro 2 es: {mi_libro2.precio}")
print(f"El autor de el libro 2 es: {mi_libro2.autor}")
print(f"El nombre de el libro es: {mi_libro2.nombre_libro}")


mi_libro1.precio = 190000
print(f"El precio de el libro 1 es: {mi_libro1.precio}  Autor:(mi_libro1.autor)")

mi_libro2.precio = 150000
print(f"El precio de el libro 2 es: {mi_libro2.precio} Autor:(mi_libro2.autor)")

print(f"\nEl libro 1: {mi_libro1.nombre_libro} Autor: {mi_libro1.autor}, Precio: {mi_libro1.precio}, Codigo: {mi_libro1.codigo}")
print(f"\nEl libro 2: {mi_libro2.nombre_libro} Autor: {mi_libro2.autor}, Precio {mi_libro2.precio}, Codigo: {mi_libro2.codigo}")
# Out:
# Abc123
# Don quijote
# Miguel Cervantes
# 8000
# Def456
# Satanas
# Mario mendoza
# 20000
# Ghi789
# Sapiens
# Yubal noah jarari
# 30000
#
# El codigo de el libro es: Abc123
# El precio de el libro 1 es: 8000
# El autor de el libro 1 es: Miguel Cervantes
# El nombre de el libro es: Don quijote
#
# El codigo de el libro es : Def456
# El precio de el libro 2 es: 20000
# El autor de el libro 2 es: Mario mendoza
# El nombre de el libro es: Satanas
# El precio de el libro 1 es: 190000  Autor:(mi_libro1.autor)
# El precio de el libro 2 es: 150000 Autor:(mi_libro2.autor)
#
# El libro 1: Don quijote Autor: Miguel Cervantes, Precio: 190000, Codigo: Abc123
#
# El libro 2: Satanas Autor: Mario mendoza, Precio 150000, Codigo: Def456
