# %% [markdown]
# <a href="https://colab.research.google.com/github/agj313829-crypto/Ejercicios_python_finales/blob/main/claseVehiculopadrejuan16_02_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Vehiculo:  # va a ser la clase padre
  """Clase padre: tiene un metodo comun para todos los vehiculos."""
  def mover (self):
    print("El vehiculo se esta moviendo")


  #crear las clases hijas
class Carro(Vehiculo):  # va a heredar el metodo mover de la clase padre osea de vehiculo.
        pass

class Moto(Vehiculo):
       pass


def main():
  # creare mi primer OBJETO clase padre
  print("Aqui muestro el metodo de la clase padre  ")
  vehiculo1 = Vehiculo()
  vehiculo1.mover()



  # creare mi primer OBJETO clase hijo
  print("\nLa clase hijo repetira el metodo mover () de la clase padre ")
  carro1 = Carro()
  carro1.mover()
  #crear mi segunda OBJETO clase hijo
  print("\nLa clase Moto repetira el metodo mover() de la clase padre ")
  Moto1 = Moto()
  Moto1.mover()



if __name__ == "__main__":
  main()
# Out:
# Aqui muestro el metodo de la clase padre
# El vehiculo se esta moviendo
#
# La clase hijo repetira el metodo mover () de la clase padre
# El vehiculo se esta moviendo
#
# La clase Moto repetira el metodo mover() de la clase padre
# El vehiculo se esta moviendo

# %%
class Vehiculo():
  def mover(self):
    print("El vehiculo se esta moviendo\n")

class Carro(Vehiculo):   # AQUI HACERMOS LA SOBREESCRITURA DEL METODO MOVER()
  def mover(self):
    print("El CARRO se esta moviendo \n")



  def main():
    vehiculo1 = Vehiculo()
    vehiculo1.mover()
# aqui nos muestra el sobre escrito de mover() para el objeto carro1

    carro1 = Carro()
    carro1.mover()
  if __name__ == "__main__":
      main()
# Out:
# El vehiculo se esta moviendo
#
# El CARRO se esta moviendo

# %%
class Vehiculo:
  def mover(self):
    print("El barco se esta moviendo\n")

class Barco(Vehiculo):
  def mover(self):
    print("El Barco navega en islas desconocidas \n")   # AQUI HACEMOS LA SOBREESCRITURA DEL METODO MOVER()


  def main():
    vehiculo1 = Vehiculo()
    vehiculo1.mover()

# aqui nos muestra el sobre escrito de mover() para el objeto barco1
    barco1 = Barco()
    barco1.mover()
  if __name__ == "__main__":
    main()
# Out:
# El barco se esta moviendo
#
# El Barco navega en islas desconocidas

# %%
class Vehiculo:
  def mover(self):
    print("El Avion se esta moviendo \n")

class Avion(Vehiculo):
  def mover(self):
    print("El Avion esta volando sobre las piramidez de egipto \n")    #AQUI HACEMOS LA SOBREESCRITURAA DEL METODO MOVER()


def main():
    vehiculo1 = Vehiculo()
    vehiculo1.mover()


 # aqui nos muestra el sobre escrito de mover() para el objeto avion1

    avion1 = Avion()
    avion1.mover()
if __name__ == "__main__":
    main()
# Out:
# El Avion se esta moviendo
#
# El Avion esta volando sobre las piramidez de egipto

# %%
class Vehiculo:
  def mover(self):
    print("El submarino se esta moviendo \n")


class Submarino(Vehiculo):
  def mover(self):
    print("El Submarino busea en las profundidades del oceano pacifico \n")  #aqui hacemos la sobreescritura del metodo mover()


def main():
  vehiculo1 = Vehiculo()
  vehiculo1.mover()


 #aqui nos muestra el sobre escrito de movr() para el objeto submarino1


submarino1 = Submarino()
submarino1.mover()


if __name__ == "__main__":
  main()
# Out:
# El Submarino busea en las profundidades del oceano pacifico
#
# El submarino se esta moviendo

# %%
class Padre:
  def __init__(self, mensaje, color_ojos, tipo_sangre):
    self.mensaje = mensaje
    self.color_ojos = color_ojos
    self.tipo_sangre = tipo_sangre


class Hijo(Padre):
  def __init__(self, mensaje,color_ojos, tipo_sangre, nombre , genero, estatura):
    super().__init__(mensaje, color_ojos, tipo_sangre) # Corrected: call padre's constructor  once with
    self.nombre = nombre
    self.genero = genero
    self.estatura = estatura


def main():
  obj = Hijo("Hola desde la clase padre","verdes","A-","Pedro","Masculino",1.67) #instancia
  print(f"{obj.mensaje}, {obj.nombre}, {obj.tipo_sangre} , {obj.nombre}, {obj.estatura}  \n")
  print(obj.mensaje)
  print(obj.nombre)


if __name__ == "__main__":
    main()
# Out:
# Hola desde la clase padre, Pedro, A- , Pedro, 1.67
#
# Hola desde la clase padre
# Pedro
